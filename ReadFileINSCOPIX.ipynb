# %%
import isx 
import os 
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Verify that you are in the correct Path

# %%
notebook_path = os.getcwd()
print(notebook_path)
# Out:
# \\ocean.igf.internal\invivo\RawData_lama\S1-117_NDiet

# %% [markdown]
# If you are not, change the folder as changing the path as following

# %%
file = 'recording_20180328_193003'
movie = isx.Movie.read( file + '.raw') ## the name of your file
print(movie)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 file = 'recording_20180328_193003'
# ----> 2 movie = isx.Movie.read( file + '.raw') ## the name of your file
#       3 print(movie)
#
# File ~\Inscopix\Data Processing\isx\io.py:105, in Movie.read(cls, file_path)
#      87 """
#      88 Open an existing movie from a file for reading.
#      89
#    (...)
#     102     Frames must be read using :func:`isx.Movie.get_frame`.
#     103 """
#     104 movie = cls()
# --> 105 isx._internal.c_api.isx_read_movie(file_path.encode('utf-8'), ctypes.byref(movie._ptr))
#     106 return movie
#
# File ~\Inscopix\Data Processing\isx\_internal.py:122, in _standard_errcheck(return_code, func, args)
#     120 if return_code != 0:
#     121     error_message = c_api.isx_get_last_exception_string().decode()
# ...

# %% [markdown]
# If you want to see how the movie is, plot the first *frame(0)*

# %%
frame0 = movie.get_frame_data(0)

plt.figure()
plt.imshow(frames[i],cmap='Greys_r', vmin = 600, vmax=1800)
plt.title(file)
plt.colorbar()
plt.savefig(file +'.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 frame0 = movie.get_frame_data(0)
#       3 plt.figure()
#       4 plt.imshow(frames[i],cmap='Greys_r', vmin = 600, vmax=1800)
#
# NameError: name 'movie' is not defined

# %%
# frames = []
# for i in range(300,305):
#     movie = isx.Movie.read(f'2021-10-04-16-00-02_video_sched_{i}.isxd')
#     frames.append(movie.get_frame_data(0))
# frames = np.array(frames)

# %%
            
# # frame0 = movie.get_frame_data(0)
# for i in range(5):
#     plt.figure(i)
#     plt.imshow(frames[i], vmin = 600, vmax=1800)
#     plt.title(f'2021-10-04-16-00-02_video_sched_30{i}.isxd')
#     plt.colorbar()
#     # plt.savefig(f'2021-10-04-16-00-02_video_sched_3{i}.png')
#     plt.show()
# plt.close
